# %% [markdown]
# # Data Ingestion

# %%
###Document Structure

from langchain_core.documents import Document
from langchain_community.document_loaders import TextLoader

# %%
## Text Loader

loader=TextLoader("C:/Users/Pratikesh/Documents/VS_CODE/LLM_RAG_practices/Langchain_pract/data/Types_of_diseases.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': 'C:/Users/Pratikesh/Documents/VS_CODE/LLM_RAG_practices/Langchain_pract/data/Types_of_diseases.txt'}, page_content="Types of Diseases and Overview\nDiseases are abnormal conditions that negatively affect the structure or function of part or all of an\norganism. They can be caused by pathogens, genetic factors, environmental conditions, or lifestyle\nchoices.\n1. Infectious Diseases\nInfectious diseases are caused by microorganisms such as bacteria, viruses, fungi, or parasites.\nThese diseases can spread directly or indirectly from one person to another. Examples include\ninfluenza, tuberculosis, and COVID-19.\n2. Non-Infectious Diseases\nNon-infectious diseases are not caused by pathogens and cannot be transmitted between\nindividuals. These include chronic conditions such as diabetes, cancer, and heart disease.\n3. Genetic Diseases\nGenetic diseases are caused by abnormalities in an individual’s DNA. These can be inherited from\nparents or occur due to
# ...

# %%
#pdfloader

from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "C:/Users/Pratikesh/Documents/VS_CODE/LLM_RAG_practices/Langchain_pract/data",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-10T10:36:42+00:00', 'source': 'C:\\Users\\Pratikesh\\Documents\\VS_CODE\\LLM_RAG_practices\\Langchain_pract\\data\\types_of_diseases.pdf', 'file_path': 'C:\\Users\\Pratikesh\\Documents\\VS_CODE\\LLM_RAG_practices\\Langchain_pract\\data\\types_of_diseases.pdf', 'total_pages': 4, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-04-10T10:36:42+00:00', 'trapped': '', 'modDate': "D:20260410103642+00'00'", 'creationDate': "D:20260410103642+00'00'", 'page': 0}, page_content='Types of Diseases and Overview\nDiseases are abnormal conditions that negatively affect the structure or function of part or all of an\norganism. They can be caused by pathogens, genetic factors, environmental conditions, or lifestyle\nchoices.\n1. Infectious Diseases\nInfectious diseases are caused by microorganisms
# ...

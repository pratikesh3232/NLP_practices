# %% [markdown]
# <a href="https://colab.research.google.com/github/pratikesh3232/NLP_practices/blob/main/GPT_2_pract(Inspect_attn_mask).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load GPT-2

# %%
pip install transformers torch

# %%
from transformers import GPT2Model,GPT2Tokenizer
import torch
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2Model.from_pretrained(
    "gpt2",
    output_attentions=True   # ✅ important
)

# %% [markdown]
# # Tokenize Input

# %%
text = "i am new in NLP"
input = tokenizer(text,return_tensors="pt")

# %%
input
# Out:
# {'input_ids': tensor([[   72,   716,   649,   287,   399, 19930]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}

# %% [markdown]
# # Forward Pass with Attention Outputs

# %%
outputs = model(**input, output_attentions=True)
attentions = outputs.attentions

# %%
attn = attentions[0][0, 0]
print(attn)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.8934, 0.1066, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.4554, 0.3519, 0.1928, 0.0000, 0.0000, 0.0000],
#         [0.4034, 0.3653, 0.1757, 0.0555, 0.0000, 0.0000],
#         [0.4759, 0.1591, 0.1063, 0.1020, 0.1567, 0.0000],
#         [0.3095, 0.1459, 0.1361, 0.1865, 0.1494, 0.0726]],
#        grad_fn=<SelectBackward0>)
